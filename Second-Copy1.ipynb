# %%
import numpy as np
import pandas as pd
from kmodes.kmodes import KModes

# %%
df = pd.read_csv('asset/agaricus-lepiota.csv')

# %%
df
# Out:
#       poisonous   convex  smooth   brown    bruises  pungent      free  \
# 0        edible   convex  smooth  yellow    bruises   almond      free
# 1        edible     bell  smooth   white    bruises    anise      free
# 2     poisonous   convex   scaly   white    bruises  pungent      free
# 3        edible   convex  smooth    gray  nobruises     none      free
# 4        edible   convex   scaly  yellow    bruises   almond      free
# ...         ...      ...     ...     ...        ...      ...       ...
# 8118     edible  knobbed  smooth   brown  nobruises     none  attached
# 8119     edible   convex  smooth   brown  nobruises     none  attached
# 8120     edible     flat  smooth   brown  nobruises     none  attached
# 8121  poisonous  knobbed   scaly   brown  nobruises    fishy      free
# 8122     edible   convex  smooth   brown  nobruises     none  attached
#
#         close  narrow   black  ... smooth.2   white white.1  partial white.2  \
# 0       close   broad   black  ...   smooth   white   white  partial   white
# 1       close   broad   brown  ...   smooth   white   white  partial   white
# 2       close  narrow   brown  ...   smooth   white   white  partial   white
# 3     crowded   broad   black  ...   smooth   white   white  partial   white
# 4       close   broad   brown  ...   smooth   white   white  partial   white
# ...       ...     ...     ...  ...      ...     ...     ...      ...     ...
# 8118    close   broad  yellow  ...   smooth  orange  orange  partial  orange
# 8119    close   broad  yellow  ...   smooth  orange  orange  partial   brown
# 8120    close   broad   brown  ...   smooth  orange  orange  partial  orange
# 8121    close  narrow    buff  ...    silky   white   white  partial   white
# 8122    close   broad  yellow  ...   smooth  orange  orange  partial  orange
#
#       one     pendant black.1  scattered    urban
# 0     one     pendant   brown   numerous  grasses
# 1     one     pendant   brown   numerous  meadows
# 2     one     pendant   black  scattered    urban
# 3     one  evanescent   brown   abundant  grasses
# 4     one     pendant   black   numerous  grasses
# ...   ...         ...     ...        ...      ...
# 8118  one     pendant    buff  clustered   leaves
# 8119  one     pendant    buff    several   leaves
# 8120  one     pendant    buff  clustered   leaves
# 8121  one  evanescent   white    several   leaves
# 8122  one     pendant  orange  clustered   leaves
#
# [8123 rows x 23 columns]

# %%
df.describe()
# Out:
#        poisonous  convex smooth  brown    bruises pungent  free  close narrow  \
# count       8123    8123   8123   8123       8123    8123  8123   8123   8123
# unique         2       6      4     10          2       9     2      2      2
# top       edible  convex  scaly  brown  nobruises    none  free  close  broad
# freq        4208    3655   3244   2283       4748    3528  7913   6811   5612
#
#        black  ... smooth.2  white white.1  partial white.2   one  pendant  \
# count   8123  ...     8123   8123    8123     8123    8123  8123     8123
# unique    12  ...        4      9       9        1       4     3        5
# top     buff  ...   smooth  white   white  partial   white   one  pendant
# freq    1728  ...     4935   4463    4383     8123    7923  7487     3967
#
#        black.1 scattered  urban
# count     8123      8123   8123
# unique       9         6      7
# top      white   several  woods
# freq      2388      4040   3148
#
# [4 rows x 23 columns]

# %%
dfTarget = df.iloc[:, 0]
dfFeature = df.drop(df.columns[0], axis=1)

# %%
dfFeature
dfTarget
# Out:
# 0          edible
# 1          edible
# 2       poisonous
# 3          edible
# 4          edible
#           ...
# 8118       edible
# 8119       edible
# 8120       edible
# 8121    poisonous
# 8122       edible
# Name: poisonous, Length: 8123, dtype: object

# %%
dfFinal = pd.concat([dfFeature, dfTarget], axis = 1)
dfFinal.head()
# Out:
#    convex  smooth   brown    bruises  pungent  free    close  narrow  black  \
# 0  convex  smooth  yellow    bruises   almond  free    close   broad  black
# 1    bell  smooth   white    bruises    anise  free    close   broad  brown
# 2  convex   scaly   white    bruises  pungent  free    close  narrow  brown
# 3  convex  smooth    gray  nobruises     none  free  crowded   broad  black
# 4  convex   scaly  yellow    bruises   almond  free    close   broad  brown
#
#    enlarging  ...  white white.1  partial white.2  one     pendant black.1  \
# 0  enlarging  ...  white   white  partial   white  one     pendant   brown
# 1  enlarging  ...  white   white  partial   white  one     pendant   brown
# 2  enlarging  ...  white   white  partial   white  one     pendant   black
# 3   tapering  ...  white   white  partial   white  one  evanescent   brown
# 4  enlarging  ...  white   white  partial   white  one     pendant   black
#
#    scattered    urban  poisonous
# 0   numerous  grasses     edible
# 1   numerous  meadows     edible
# 2  scattered    urban  poisonous
# 3   abundant  grasses     edible
# 4   numerous  grasses     edible
#
# [5 rows x 23 columns]

# %%
km = KModes(n_clusters=3, init='Huang', n_init=5, verbose=1)

# %%
clusters = km.fit_predict(dfFinal)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1841, cost: 55570.0
# Run 1, iteration: 2/100, moves: 582, cost: 55570.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1850, cost: 62640.0
# Run 2, iteration: 2/100, moves: 397, cost: 61828.0
# Run 2, iteration: 3/100, moves: 1205, cost: 59422.0
# Run 2, iteration: 4/100, moves: 838, cost: 58264.0
# Run 2, iteration: 5/100, moves: 832, cost: 57884.0
# Run 2, iteration: 6/100, moves: 300, cost: 57763.0
# Run 2, iteration: 7/100, moves: 55, cost: 57763.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 397, cost: 55547.0
# Run 3, iteration: 2/100, moves: 7, cost: 55547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 986, cost: 57733.0
# Run 4, iteration: 2/100, moves: 452, cost: 57440.0
# Run 4, iteration: 3/100, moves: 202, cost: 57415.0
# Run 4, iteration: 4/100, moves: 249, cost: 57292.0
# Run 4, iteration: 5/100, moves: 3, cost: 57292.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 2545, cost: 58160.0
# Run 5, iteration: 2/100, moves: 1670, cost: 55538.0
# Run 5, iteration: 3/100, moves: 224, cost: 55538.0
# Best run was number 5

# %%
kmodes = km.cluster_centroids_
shape = kmodes.shape
shape
# Out:
# (3, 23)

# %%
print(kmodes)
# Out:
# [['convex' 'scaly' 'brown' 'bruises' 'none' 'free' 'close' 'broad'
#   'white' 'tapering' 'bulbous' 'smooth' 'smooth' 'white' 'white'
#   'partial' 'white' 'one' 'pendant' 'brown' 'several' 'woods' 'edible']
#  ['convex' 'smooth' 'red' 'nobruises' 'spicy' 'free' 'close' 'narrow'
#   'buff' 'tapering' 'missing' 'smooth' 'smooth' 'white' 'white' 'partial'
#   'white' 'one' 'evanescent' 'white' 'several' 'woods' 'poisonous']
#  ['convex' 'fibrous' 'gray' 'nobruises' 'foul' 'free' 'close' 'broad'
#   'pink' 'enlarging' 'bulbous' 'silky' 'silky' 'brown' 'brown' 'partial'
#   'white' 'one' 'large' 'chocolate' 'several' 'grasses' 'poisonous']]

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
pca = PCA(2)

# %%
dfFinal.iloc[:,0:22]
# Out:
#        convex  smooth   brown    bruises  pungent      free    close  narrow  \
# 0      convex  smooth  yellow    bruises   almond      free    close   broad
# 1        bell  smooth   white    bruises    anise      free    close   broad
# 2      convex   scaly   white    bruises  pungent      free    close  narrow
# 3      convex  smooth    gray  nobruises     none      free  crowded   broad
# 4      convex   scaly  yellow    bruises   almond      free    close   broad
# ...       ...     ...     ...        ...      ...       ...      ...     ...
# 8118  knobbed  smooth   brown  nobruises     none  attached    close   broad
# 8119   convex  smooth   brown  nobruises     none  attached    close   broad
# 8120     flat  smooth   brown  nobruises     none  attached    close   broad
# 8121  knobbed   scaly   brown  nobruises    fishy      free    close  narrow
# 8122   convex  smooth   brown  nobruises     none  attached    close   broad
#
#        black  enlarging  ... smooth.2   white white.1  partial white.2  one  \
# 0      black  enlarging  ...   smooth   white   white  partial   white  one
# 1      brown  enlarging  ...   smooth   white   white  partial   white  one
# 2      brown  enlarging  ...   smooth   white   white  partial   white  one
# 3      black   tapering  ...   smooth   white   white  partial   white  one
# 4      brown  enlarging  ...   smooth   white   white  partial   white  one
# ...      ...        ...  ...      ...     ...     ...      ...     ...  ...
# 8118  yellow  enlarging  ...   smooth  orange  orange  partial  orange  one
# 8119  yellow  enlarging  ...   smooth  orange  orange  partial   brown  one
# 8120   brown  enlarging  ...   smooth  orange  orange  partial  orange  one
# 8121    buff   tapering  ...    silky   white   white  partial   white  one
# 8122  yellow  enlarging  ...   smooth  orange  orange  partial  orange  one
#
#          pendant black.1  scattered    urban
# 0        pendant   brown   numerous  grasses
# 1        pendant   brown   numerous  meadows
# 2        pendant   black  scattered    urban
# 3     evanescent   brown   abundant  grasses
# 4        pendant   black   numerous  grasses
# ...          ...     ...        ...      ...
# 8118     pendant    buff  clustered   leaves
# 8119     pendant    buff    several   leaves
# 8120     pendant    buff  clustered   leaves
# 8121  evanescent   white    several   leaves
# 8122     pendant  orange  clustered   leaves
#
# [8123 rows x 22 columns]

# %%
dfFeature = df.drop('poisonous',axis=1)

# %%
import prince
mca = prince.MCA(n_components=2,n_iter=3,copy=True,check_input=True,engine='auto',random_state=42)
mca = mca.fit(dfFeature)
# Out:
# /home/compsci/.local/lib/pyenv/lib/python3.7/site-packages/prince/one_hot.py:35: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   default_fill_value=0
# /home/compsci/.local/lib/pyenv/lib/python3.7/site-packages/pandas/core/sparse/frame.py:257: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   sparse_index=BlockIndex(N, blocs, blens),
# /home/compsci/.local/lib/pyenv/lib/python3.7/site-packages/pandas/core/frame.py:3456: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
# /home/compsci/.local/lib/pyenv/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1641: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return self._constructor(new_values, index=self.index, name=self.name)
# /home/compsci/.local/lib/pyenv/lib/python3.7/site-packages/pandas/core/sparse/frame.py:339: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   default_fill_value=self.default_fill_value,
# /home/compsci/.local/lib/pyenv/lib/python3.7/site-packages/pandas/core/generic.py:6289: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return self._constructor(new_data).__finalize__(self)
# /home/compsci/.local/lib/pyenv/lib/python3.7/site-packages/pandas/core/generic.py:5884: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return self._constructor(new_data).__finalize__(self)
